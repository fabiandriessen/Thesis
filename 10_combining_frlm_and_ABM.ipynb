# %%
import pandas as pd
from fullfrlm import flow_refueling_location_model
from get_abm_data import get_cs_data_batch, get_vessel_data_batch
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %%time
# for seed in seeds:
total_flow, fraction_captured_total, serviceable_fraction, served_fraction, optimal_facilities1, non_zero_flows, routes_supported, paths, G, df_abm, df_random_out, max_flow, nodes_used = flow_refueling_location_model(150000, 90, 2000, 5, vis=True, additional_nodes=3)
# Out:
# There were 25 nodes added, the longest remaining link is now: 35117.6542642193
# ['8863114', '8864435', '8865887', '8861447', '8864526', '8860631', '8863272', '8863762', '8861611', '8860623', '8864952', '8864915', '8860563', '8860918', '8862907', '8865462', '8860579', '8861863', '8866661', '8864151', '8864912', '8864258', '8861499', '8864553', '8865119'] intersections added
# CPU times: total: 2min 15s
# Wall time: 3min 8s

# %%
supported_routes = list(non_zero_flows.keys())

# %%
batch_data = pickle.load(open('ABM/own_work/data/batch_run_result.p', 'rb'))

# %%
df = pd.DataFrame(batch_data)

# %%
df
# Out:
#         RunId  iteration   Step    seed  \
# 0           0          0      0  194081
# 1           0          0      0  194081
# 2           0          0      0  194081
# 3           0          0      0  194081
# 4           0          0      0  194081
# ...       ...        ...    ...     ...
# 118299     99          0  11520  131322
# 118300     99          0  11520  131322
# 118301     99          0  11520  131322
# 118302     99          0  11520  131322
# 118303     99          0  11520  131322
#
#                                      data_completed_trips  \
# 0       {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...
# 1       {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...
# 2       {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...
# 3       {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...
# 4       {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...
# ...                                                   ...
# 118299  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...
# 118300  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...
# 118301  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...
# 118302  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...
# 118303  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...
#
#                        AgentID  occupation  max_occupation  avg_line  \
# 0       ('8864153', '8860579')         NaN             NaN       NaN
# 1       ('8864153', '8868168')         NaN             NaN       NaN
# 2       ('8868065', '8862419')         NaN             NaN       NaN
# 3       ('8868065', '8866297')         NaN             NaN       NaN
# 4       ('8868065', '8863614')         NaN             NaN       NaN
# ...                        ...         ...             ...       ...
# 118299                    8018         NaN             NaN       NaN
# 118300                    8019         NaN             NaN       NaN
# 118301                    8020         NaN             NaN       NaN
# 118302                    8021         NaN             NaN       NaN
# 118303                    8022         NaN             NaN       NaN
#
#         max_line  charging_stations
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
# ...          ...                ...
# 118299       NaN                NaN
# 118300       NaN                NaN
# 118301       NaN                NaN
# 118302       NaN                NaN
# 118303       NaN                NaN
#
# [118304 rows x 11 columns]

# %%
df_cs = get_cs_data_batch(batch_data)

# %%
df_cs
# Out:
#         RunId  iteration   Step    seed  \
# 737         0          0  11520  194081
# 741         0          0  11520  194081
# 750         0          0  11520  194081
# 755         0          0  11520  194081
# 757         0          0  11520  194081
# ...       ...        ...    ...     ...
# 118000     99          0  11520  131322
# 118001     99          0  11520  131322
# 118005     99          0  11520  131322
# 118017     99          0  11520  131322
# 118024     99          0  11520  131322
#
#                                      data_completed_trips   AgentID  \
# 737     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8864153
# 741     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8868208
# 750     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...  30984595
# 755     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8860582
# 757     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8862419
# ...                                                   ...       ...
# 118000  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8867083
# 118001  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863306
# 118005  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863125
# 118017  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863518
# 118024  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8862448
#
#         occupation  max_occupation  avg_line  max_line  charging_stations
# 737       0.239385             1.0  0.015377       1.0                1.0
# 741       0.858631             1.0  1.427480       5.0                1.0
# 750       0.702083             1.0  0.489881       2.0                1.0
# 755       0.026290             1.0  0.000000       0.0                1.0
# 757       0.118452             1.0  0.009325       1.0                1.0
# ...            ...             ...       ...       ...                ...
# 118000    0.162103             1.0  0.014583       1.0                1.0
# 118001    0.885317             1.0  2.335218       7.0                1.0
# 118005    0.267460             1.0  0.075099       1.0                1.0
# 118017    0.022024             1.0  0.000000       0.0                1.0
# 118024    0.335615             1.0  0.034524       1.0                1.0
#
# [4900 rows x 11 columns]

# %%
df_cs.AgentID.unique()
# Out:
# array(['8864153', '8868208', '30984595', '8860582', '8862419', '8863818',
#        '8865412', '8862497', '22638146', '8862992', '8866686', '8867258',
#        '8867240', '8866775', '8863709', '8862776', '8865756', '8863599',
#        '8867392', '8866429', '8868191', '8866564', '22637863', '8864494',
#        '8861546', '8867824', '8866893', '8861625', '22638327', '22638404',
#        '8864005', '8864020', '8863206', '8861528', '30986757', '8865600',
#        '8864111', '8866297', '8866671', '8867130', '8863207', '8862570',
#        '8866748', '8863360', '8867083', '8863306', '8863125', '8863518',
#        '8862448'], dtype=object)

# %%
import numpy as np
plt.subplots(dpi=200)
sns.boxplot(x='AgentID', y='occupation', data=df_cs)
plt.title('Average occupation charging stations')
plt.xticks(np.arange(0, 48))
# Out:
# ([<matplotlib.axis.XTick at 0x1ec8caaaaa0>,
#   <matplotlib.axis.XTick at 0x1ec8caa9990>,
#   <matplotlib.axis.XTick at 0x1ec8cb9d360>,
#   <matplotlib.axis.XTick at 0x1ec8cec3d90>,
#   <matplotlib.axis.XTick at 0x1ec8cec3280>,
#   <matplotlib.axis.XTick at 0x1ec8cfc29e0>,
#   <matplotlib.axis.XTick at 0x1ec8cec3940>,
#   <matplotlib.axis.XTick at 0x1ec8cec20e0>,
#   <matplotlib.axis.XTick at 0x1ec8cec1750>,
#   <matplotlib.axis.XTick at 0x1ec8cec0d30>,
#   <matplotlib.axis.XTick at 0x1ec8cec0460>,
#   <matplotlib.axis.XTick at 0x1ec8cec12a0>,
#   <matplotlib.axis.XTick at 0x1ec8cec0430>,
#   <matplotlib.axis.XTick at 0x1ec8cec1bd0>,
#   <matplotlib.axis.XTick at 0x1ec8cec2ce0>,
#   <matplotlib.axis.XTick at 0x1ec8cee7640>,
#   <matplotlib.axis.XTick at 0x1ec8cee6cb0>,
#   <matplotlib.axis.XTick at 0x1ec8cee5b70>,
#   <matplotlib.axis.XTick at 0x1ec8cec3bb0>,
#   <matplotlib.axis.XTick at 0x1ec8cec0370>,
#   <matplotlib.axis.XTick at 0x1ec8cee6bc0>,
#   <matplotlib.axis.XTick at 0x1ec8cee47c0>,
#   <matplotlib.axis.XTick at 0x1ec8cee4be0>,
#   <matplotlib.axis.XTick at 0x1ec8cee6380>,
#   <matplotlib.axis.XTick at 0x1ec8cee7850>,
#   <matplotlib.axis.XTick at 0x1ec8cee6980>,
#   <matplotlib.axis.XTick at 0x1ec8cee46d0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b3fd0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b3430>,
#   <matplotlib.axis.XTick at 0x1ec8e9b2ad0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b2020>,
#   <matplotlib.axis.XTick at 0x1ec8e9b1690>,
#   <matplotlib.axis.XTick at 0x1ec8cee42b0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b2590>,
#   <matplotlib.axis.XTick at 0x1ec8e9b1060>,
#   <matplotlib.axis.XTick at 0x1ec8e9b06d0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b14e0>,
#   <matplotlib.axis.XTick at 0x1ec8e9c77c0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b2dd0>,
#   <matplotlib.axis.XTick at 0x1ec8e9b0b50>,
#   <matplotlib.axis.XTick at 0x1ec8cee5900>,
#   <matplotlib.axis.XTick at 0x1ec8e9c7940>,
#   <matplotlib.axis.XTick at 0x1ec8e9c6dd0>,
#   <matplotlib.axis.XTick at 0x1ec8e9c5d50>,
#   <matplotlib.axis.XTick at 0x1ec8e9c5150>,
#   <matplotlib.axis.XTick at 0x1ec8cee4eb0>,
#   <matplotlib.axis.XTick at 0x1ec8e9c4fd0>,
#   <matplotlib.axis.XTick at 0x1ec8e9c7670>],
#  [Text(0, 0, '8864153'),
#   Text(1, 0, '8868208'),
#   Text(2, 0, '30984595'),
#   Text(3, 0, '8860582'),
#   Text(4, 0, '8862419'),
#   Text(5, 0, '8863818'),
#   Text(6, 0, '8865412'),
#   Text(7, 0, '8862497'),
#   Text(8, 0, '22638146'),
#   Text(9, 0, '8862992'),
#   Text(10, 0, '8866686'),
#   Text(11, 0, '8867258'),
#   Text(12, 0, '8867240'),
#   Text(13, 0, '8866775'),
#   Text(14, 0, '8863709'),
#   Text(15, 0, '8862776'),
#   Text(16, 0, '8865756'),
#   Text(17, 0, '8863599'),
#   Text(18, 0, '8867392'),
#   Text(19, 0, '8866429'),
#   Text(20, 0, '8868191'),
#   Text(21, 0, '8866564'),
#   Text(22, 0, '22637863'),
#   Text(23, 0, '8864494'),
#   Text(24, 0, '8861546'),
#   Text(25, 0, '8867824'),
#   Text(26, 0, '8866893'),
#   Text(27, 0, '8861625'),
#   Text(28, 0, '22638327'),
#   Text(29, 0, '22638404'),
#   Text(30, 0, '8864005'),
#   Text(31, 0, '8864020'),
#   Text(32, 0, '8863206'),
#   Text(33, 0, '8861528'),
#   Text(34, 0, '30986757'),
#   Text(35, 0, '8865600'),
#   Text(36, 0, '8864111'),
#   Text(37, 0, '8866297'),
#   Text(38, 0, '8866671'),
#   Text(39, 0, '8867130'),
#   Text(40, 0, '8863207'),
#   Text(41, 0, '8862570'),
#   Text(42, 0, '8866748'),
#   Text(43, 0, '8863360'),
#   Text(44, 0, '8867083'),
#   Text(45, 0, '8863306'),
#   Text(46, 0, '8863125'),
#   Text(47, 0, '8863518')])

# %%
df_cs
# Out:
#         RunId  iteration   Step    seed  \
# 737         0          0  11520  194081
# 741         0          0  11520  194081
# 750         0          0  11520  194081
# 755         0          0  11520  194081
# 757         0          0  11520  194081
# ...       ...        ...    ...     ...
# 118000     99          0  11520  131322
# 118001     99          0  11520  131322
# 118005     99          0  11520  131322
# 118017     99          0  11520  131322
# 118024     99          0  11520  131322
#
#                                      data_completed_trips   AgentID  \
# 737     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8864153
# 741     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8868208
# 750     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...  30984595
# 755     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8860582
# 757     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8862419
# ...                                                   ...       ...
# 118000  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8867083
# 118001  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863306
# 118005  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863125
# 118017  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863518
# 118024  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8862448
#
#         occupation  max_occupation  avg_line  max_line  charging_stations
# 737       0.239385             1.0  0.015377       1.0                1.0
# 741       0.858631             1.0  1.427480       5.0                1.0
# 750       0.702083             1.0  0.489881       2.0                1.0
# 755       0.026290             1.0  0.000000       0.0                1.0
# 757       0.118452             1.0  0.009325       1.0                1.0
# ...            ...             ...       ...       ...                ...
# 118000    0.162103             1.0  0.014583       1.0                1.0
# 118001    0.885317             1.0  2.335218       7.0                1.0
# 118005    0.267460             1.0  0.075099       1.0                1.0
# 118017    0.022024             1.0  0.000000       0.0                1.0
# 118024    0.335615             1.0  0.034524       1.0                1.0
#
# [4900 rows x 11 columns]

# %%
plt.subplots(dpi=200)
sns.boxplot(x='AgentID', y='avg_line', data=df_cs)
plt.title('Average line length')
# Out:
# Text(0.5, 1.0, 'Average line length')

# %%
df_vessels = get_vessel_data_batch(batch_data)

# %%
plt.subplots(dpi=500)
sns.boxplot(x='route', y='time_in_line', data=df_vessels)
plt.title('Time in line')
# Out:
# Text(0.5, 1.0, 'Time in line')

# %%
df_vessels
# Out:
#         id              route                        combi  generation_hour  \
# 0        4  (NLTNZ, NLVLI, 0)                    [8864111]               14
# 1       14  (NLGOR, NLRTM, 0)                    [8863306]               10
# 2       29  (NLDOR, NLRTM, 0)                    [8863306]               20
# 3        7  (NLAMS, NLAER, 0)                    [8864005]               11
# 4       23  (NLRTM, NLGTB, 1)                    [8866893]                3
# ...    ...                ...                          ...              ...
# 1335  7524  (NLRTM, NLAMS, 1)           [8866429, 8862776]               10
# 1336  7946  (NLDST, NLAMS, 0)           [8865412, 8866429]                8
# 1337  7492  (NLVLI, NLAMS, 1)  [8862992, 8866686, 8867392]                9
# 1338  7815  (NLWGW, NLRTM, 0)           [8866686, 8865412]               12
# 1339  7979  (NLAMS, NLAER, 0)                    [8864005]               16
#
#       time_departed  travel_time  time_in_line  time_charging  battery_size
# 0                14          110             0              0         20150
# 1               107          238             0              0          6900
# 2               240          127             0              0          6900
# 3                35          225             0            145          6900
# 4               198          264             0              0          6900
# ...             ...          ...           ...            ...           ...
# 1335           8017          579          2632           2885         14250
# 1336          10921          478             0             84          4350
# 1337           7870         1222          1698           2401         14250
# 1338          10021          506           909            962          3000
# 1339          11197          225             0             92          4350
#
# [136142 rows x 9 columns]

# %%
df_hourp = df_vessels.groupby('generation_hour').count()

# %%
df_ivs = pickle.load(open("data/revised_cleaning_results/ivs_exploded_100.p", "rb"))

# %%
def create_key(o, d, r_v):
    key1 = (o, d, r_v)
    return key1

# %%
df_ivs['key'] = df_ivs.apply(lambda x: create_key(x.origin, x.destination, x.route_v), axis=1)

# %%
supported_routes = list(df_vessels.route.unique())

# %%
supported_routes
# Out:
# [('NLTNZ', 'NLVLI', 0),
#  ('NLGOR', 'NLRTM', 0),
#  ('NLDOR', 'NLRTM', 0),
#  ('NLAMS', 'NLAER', 0),
#  ('NLRTM', 'NLGTB', 1),
#  ('NLRTM', 'NLMOE', 0),
#  ('NLBON', 'NLSTI', 0),
#  ('NLLEY', 'NLAMS', 0),
#  ('NLVEN', 'NLBON', 0),
#  ('NLAMS', 'NLIJM', 0),
#  ('NLABL', 'NLRTM', 0),
#  ('NLWSP', 'NLAER', 0),
#  ('NLALK', 'NLIJM', 0),
#  ('NLRTM', 'NLMOE', 1),
#  ('NLBZM', 'NLRTM', 0),
#  ('NLMEP', 'NLZWS', 0),
#  ('NLAER', 'NLRTM', 0),
#  ('NLVEG', 'NLRTM', 0),
#  ('NLZWO', 'NLAMS', 0),
#  ('NLMAA', 'NLCUY', 0),
#  ('NLAMS', 'NLHEJ', 0),
#  ('NLRTM', 'NLAMS', 1),
#  ('NLNIJ', 'NLWAS', 0),
#  ('NLDST', 'NLAMS', 0),
#  ('NLRTM', 'NLOOS', 1),
#  ('NLDRO', 'NLKAM', 0),
#  ('NLOSS', 'NLRTM', 0),
#  ('NLRTM', 'NLAMS', 2),
#  ('NLSWI', 'NLNKK', 0),
#  ('NLNIJ', 'NLABL', 0),
#  ('NLAMS', 'NLLOB', 0),
#  ('NLLMR', 'NLAMS', 0),
#  ('NLMOE', 'NLOOS', 0),
#  ('NLRTM', 'NLLID', 0),
#  ('NLTIE', 'NLRTM', 0),
#  ('NLTNZ', 'NLBRS', 0),
#  ('NLSWI', 'NLWSP', 0),
#  ('NLAMS', 'NLDEV', 0),
#  ('NLVEG', 'NLHEJ', 0),
#  ('NLAMS', 'NLMOE', 2),
#  ('NLLEY', 'NLLWR', 0),
#  ('NLRTM', 'NLAPN', 0),
#  ('NLAER', 'NLLEY', 0),
#  ('NLUTC', 'NLRTM', 0),
#  ('NLWGW', 'NLRTM', 0),
#  ('NLIJM', 'NLRTM', 2),
#  ('NLAMS', 'NLMOE', 3),
#  ('NLDOR', 'NLVLI', 0),
#  ('NLRTM', 'NLVSN', 2),
#  ('NLPER', 'NLAMS', 3),
#  ('NLBON', 'NLRTM', 1),
#  ('NLWSP', 'NLLEY', 0),
#  ('NLNIJ', 'NLPER', 0),
#  ('NLKAM', 'NLAMS', 0),
#  ('NLRTM', 'NLVLA', 0),
#  ('NLAER', 'NLSWI', 0),
#  ('NLMST', 'NLBON', 0),
#  ('NLRTM', 'NLNIJ', 0),
#  ('NLLCH', 'NLAMS', 0),
#  ('NLAMS', 'NLNWG', 0),
#  ('NLNER', 'NLVEN', 0),
#  ('NLOOS', 'NLTLB', 0),
#  ('NLRTM', 'NLALM', 0),
#  ('NLNWG', 'NLRTM', 0),
#  ('NLWKD', 'NLAMS', 1),
#  ('NLNKK', 'NLAMS', 0),
#  ('NLRTM', 'NLARN', 0),
#  ('NLRTM', 'NLTNZ', 0),
#  ('NLNIJ', 'NLVEN', 0),
#  ('NLTNZ', 'NLHAN', 0),
#  ('NLMOE', 'NLSLU', 0),
#  ('NLNIJ', 'NLDRU', 0),
#  ('NLRTM', 'NLWLK', 1),
#  ('NLHAR', 'NLDRA', 0),
#  ('NLUTC', 'NLTIE', 0),
#  ('NLDOR', 'NLAMS', 4),
#  ('NLGTB', 'NLAMS', 1),
#  ('NLRTM', 'NLSLU', 1),
#  ('NLAMS', 'NLWGW', 0),
#  ('NLSLU', 'NLBRS', 0),
#  ('NLRLA', 'NLRTM', 1),
#  ('NLRTM', 'NLVLI', 0),
#  ('NLSWI', 'NLLEY', 0),
#  ('NLHAR', 'NLKAM', 0),
#  ('NLALM', 'NLAMS', 0),
#  ('NLTLB', 'NLRTM', 1),
#  ('NLRTM', 'NLZWI', 0),
#  ('NLMOE', 'NLTNZ', 0),
#  ('NLDOR', 'NLAMS', 3),
#  ('NLTLB', 'NLMOE', 0),
#  ('NLRTM', 'NLSLU', 0),
#  ('NLRTM', 'NLNGV', 0),
#  ('NLCUY', 'NLRTM', 0),
#  ('NLAMS', 'NLMAA', 0),
#  ('NLAER', 'NLNIE', 0),
#  ('NLAMS', 'NLUTC', 1),
#  ('NLTNZ', 'NLAMS', 3),
#  ('NLIJM', 'NLMST', 1),
#  ('NLSTI', 'NLRTM', 1),
#  ('NLRTM', 'NLDOE', 0),
#  ('NLMSB', 'NLRTM', 1),
#  ('NLHGL', 'NLRTM', 0),
#  ('NLAMS', 'NLBON', 1),
#  ('NLWED', 'NLRTM', 0),
#  ('NLOMD', 'NLWAS', 0),
#  ('NLOMD', 'NLRTM', 1),
#  ('NLHGL', 'NLAMS', 0),
#  ('NLHAN', 'NLBRS', 0),
#  ('NLMSB', 'NLBON', 0),
#  ('NLMOE', 'NLVLI', 0),
#  ('NLAMS', 'NLTIE', 0),
#  ('NLBZM', 'NLVLI', 0),
#  ('NLMOE', 'NLAPN', 1),
#  ('NLWAS', 'NLRTM', 0),
#  ('NLSTI', 'NLAMS', 1),
#  ('NLRTM', 'NLMST', 1),
#  ('NLHAR', 'NLAMS', 0),
#  ('NLVLI', 'NLHAN', 0),
#  ('NLRTM', 'NLDEV', 0),
#  ('NLHTB', 'NLBZM', 0),
#  ('NLHTB', 'NLRTM', 0),
#  ('NLRTM', 'NLAMS', 0),
#  ('NLAMS', 'NLBOT', 4),
#  ('NLAMS', 'NLOMD', 1),
#  ('NLALM', 'NLHGL', 0),
#  ('NLIJM', 'NLMOE', 1),
#  ('NLRTM', 'NLGRO', 0),
#  ('NLAMS', 'NLMOE', 4),
#  ('NLMSB', 'NLRTM', 0),
#  ('NLBNB', 'NLHGL', 0),
#  ('NLOSS', 'NLCUY', 0),
#  ('NLZAA', 'NLRTM', 2),
#  ('NLEEM', 'NLLMR', 1),
#  ('NLIJM', 'NLRTM', 0),
#  ('NLHEJ', 'NLOOS', 0),
#  ('NLAMS', 'NLZWI', 1),
#  ('NLGTB', 'NLAMS', 3),
#  ('NLVLL', 'NLHAR', 0),
#  ('NLPER', 'NLVLI', 1),
#  ('NLRTM', 'NLVEN', 0),
#  ('NLBZM', 'NLBRS', 0),
#  ('NLSWI', 'NLAMS', 0),
#  ('NLRTM', 'NLBNB', 0),
#  ('NLAMS', 'NLMOE', 1),
#  ('NLVLI', 'NLAMS', 1),
#  ('NLAMS', 'NLMOE', 0),
#  ('NLIJM', 'NLRTM', 3),
#  ('NLLEY', 'NLRTM', 0),
#  ('NLHTB', 'NLABL', 0),
#  ('NLUTC', 'NLLEY', 1),
#  ('NLDOR', 'NLRTM', 1),
#  ('NLNIJ', 'NLAMS', 0),
#  ('NLNIJ', 'NLOMD', 0),
#  ('NLVLI', 'NLABL', 0),
#  ('NLTNZ', 'NLMST', 1),
#  ('NLFAR', 'NLEEM', 0),
#  ('NLZAA', 'NLRTM', 0),
#  ('NLRLA', 'NLRTM', 0),
#  ('NLAMS', 'NLEUR', 1),
#  ('NLSLU', 'NLVLI', 0),
#  ('NLVLA', 'NLSLU', 1),
#  ('NLAMS', 'NLENS', 0),
#  ('NLWSM', 'NLBON', 0),
#  ('NLAMS', 'NLVLA', 3),
#  ('NLDOR', 'NLAMS', 1),
#  ('NLBON', 'NLKSL', 1),
#  ('NLAMS', 'NLDHR', 0),
#  ('NLAMS', 'NLMSB', 1),
#  ('NLAMS', 'NLWAS', 0),
#  ('NLSJK', 'NLRTM', 0),
#  ('NLPER', 'NLAMS', 2),
#  ('NLRTM', 'NLENS', 0),
#  ('NLDOR', 'NLVLA', 0),
#  ('NLAMS', 'NLVLA', 2),
#  ('NLSTI', 'NLTNZ', 1),
#  ('NLBZM', 'NLRTM', 1),
#  ('NLAMS', 'NLZWI', 3),
#  ('NLZAA', 'NLRTM', 1),
#  ('NLVLA', 'NLSLU', 0),
#  ('NLDOR', 'NLAMS', 0),
#  ('NLAMS', 'NLZWI', 0),
#  ('NLRTM', 'NLLAV', 0),
#  ('NLAMS', 'NLVLA', 4),
#  ('NLHAR', 'NLWTE', 0),
#  ('NLTNZ', 'NLAMS', 0),
#  ('NLVLI', 'NLVLA', 1),
#  ('NLRTM', 'NLZWI', 1),
#  ('NLWGW', 'NLRTM', 1),
#  ('NLBON', 'NLKSL', 0),
#  ('NLSJK', 'NLRTM', 1),
#  ('NLIJM', 'NLRTM', 1),
#  ('NLAMS', 'NLZWI', 4),
#  ('NLRTM', 'NLVSN', 0),
#  ('NLAMS', 'NLBOT', 1),
#  ('NLIJM', 'NLMOE', 0),
#  ('NLMOE', 'NLSLU', 1),
#  ('NLAMS', 'NLBOT', 2),
#  ('NLIJM', 'NLMOE', 4),
#  ('NLTNZ', 'NLAMS', 1),
#  ('NLOMD', 'NLRTM', 0),
#  ('NLWED', 'NLRTM', 1),
#  ('NLDST', 'NLAMS', 1),
#  ('NLBON', 'NLRTM', 0),
#  ('NLCUY', 'NLRTM', 1),
#  ('NLDHR', 'NLRTM', 0),
#  ('NLAMS', 'NLWGW', 1),
#  ('NLAMS', 'NLLOB', 1),
#  ('NLSTI', 'NLRTM', 0),
#  ('NLTLB', 'NLRTM', 0)]

# %%
#subset supported routes here before we take sum!
df_ivs = df_ivs.loc[df_ivs.key.isin(supported_routes)]

# %%
df_ivs_group = df_ivs.groupby("hour").sum()

# %%
df_ivs_group
# Out:
#       trip_count  M12    M8  BII-6b  M10  BIIa-1   M9  BII-6l  C3b  BII-4  \
# hour
# 0           1406  138   643       1   57      25  160       1   37      3
# 1           1285  130   653       2   47      18  134       1   23      3
# 2           1247   93   602       0   42      14  165       0   21      3
# 3           1403   91   643       1   51      14  151       1   20      4
# 4           1844   98   730       0   74      16  156       0    5      3
# 5           2399  100   831       0   87      32  183       1   13      1
# 6           2890  101   941       1   88      33  172       0    6      4
# 7           3535  115  1135       1   89      34  174       0    9      2
# 8           4028  131  1334       0  115      48  199       1   13      2
# 9           4111  152  1383       1  110      57  198       1   12      4
# 10          4205  132  1358       0  114      51  198       0   12      5
# 11          4381  166  1341       0  116      56  198       3   22      7
# 12          4265  165  1379       0  101      58  203       0   14      4
# 13          4308  162  1266       2   99      63  218       0   18      2
# 14          4478  191  1337       0   97      73  205       1   23      2
# 15          4526  199  1417       0  117      82  185       1   26      5
# 16          4320  187  1432       2  108      73  204       0   17      0
# 17          4147  165  1461       1  104      70  189       1   27      4
# 18          3845  201  1429       0   93      57  184       1   26      4
# 19          3518  211  1346       0  102      49  185       1   28      7
# 20          2984  160  1277       0   85      40  168       0   23      5
# 21          2476  174  1051       0   87      39  187       1   33      2
# 22          1894  159   882       0   62      44  132       1   27      0
# 23          1586  157   772       0   41      21  153       0   32      4
#
#       ...  C4  B04  C2l  BII-2L  B02  C1b  C2b  B01  C1l  route_v
# hour  ...
# 0     ...   0    0    0       5    0    0    0    0    0       91
# 1     ...   0    0    0       8    0    0    0    0    0       76
# 2     ...   2    0    0       3    0    0    0    0    0       67
# 3     ...   2    0    1       2    0    0    1    0    0       74
# 4     ...   2    7    0       8    0    0    0    0    0       79
# 5     ...   0    8    1      12    1    0    1    0    0       90
# 6     ...   1    9    1      12    1    0    1    1    0       87
# 7     ...   2   17    1       9    3    0    0    1    0       92
# 8     ...   3   15    2      21    2    0    0    2    0      100
# 9     ...   1   18    2      15    3    0    0    2    0       98
# 10    ...   0   14    4      22    1    0    1    0    1       97
# 11    ...   2   20    1      19    4    0    0    1    0      100
# 12    ...   2   17    3      10    3    0    1    2    0      101
# 13    ...   1   17    5      27    6    1    1    2    1      101
# 14    ...   1   16    3      18    3    0    1    3    0       94
# 15    ...   1   17    2      17    3    1    3    2    1      101
# 16    ...   3   11    1      17    2    0    2    0    0       97
# 17    ...   4   12    3      23    2    0    0    1    0       95
# 18    ...   2   14    1      17    0    0    1    0    0       93
# 19    ...   1   14    0      15    0    0    0    0    0       98
# 20    ...   0    5    4       9    1    0    0    0    0       89
# 21    ...   2    4    0       7    0    0    0    0    0       89
# 22    ...   0    2    1       4    0    0    0    1    0       92
# 23    ...   1    2    0       6    0    0    1    0    0       83
#
# [24 rows x 34 columns]

# %%
df_ivs = pickle.load(open("data/revised_cleaning_results/ivs_exploded_100.p", "rb"))
fig, ax = plt.subplots(1, 2, dpi=200, figsize=(12,6))
sns.barplot(x=df_hourp.index, y=df_hourp.id/(100*7), ax=ax[0])
ax[0].set_ylabel('Cumulative trips [#/hour]')
ax[0].set_xlabel('Hour of departure')
ax[0].set_title('Generated data average cumulative trips in a week')

sns.barplot(x=df_ivs_group.index, y=df_ivs_group.trip_count/(52*7), ax=ax[1])
ax[1].set_ylabel('Cumulative trips [#/hour]')
ax[1].set_xlabel('Hour of departure')
ax[1].set_title('Empirical data average cumulative trips in a week')
plt.show()

# %%
from scipy import stats
stats.ttest_rel(df_hourp.id, df_ivs_group.trip_count)
# Out:
# Ttest_relResult(statistic=11.793981576999185, pvalue=3.120197747858683e-11)

# %%
df_ivs.groupby('hour').count()
# Out:
#       origin  destination  trip_count  M12   M8  BII-6b  M10  BIIa-1   M9  \
# hour
# 0        185          185         185  185  185     185  185     185  185
# 1        153          153         153  153  153     153  153     153  153
# 2        171          171         171  171  171     171  171     171  171
# 3        194          194         194  194  194     194  194     194  194
# 4        211          211         211  211  211     211  211     211  211
# 5        230          230         230  230  230     230  230     230  230
# 6        240          240         240  240  240     240  240     240  240
# 7        242          242         242  242  242     242  242     242  242
# 8        254          254         254  254  254     254  254     254  254
# 9        251          251         251  251  251     251  251     251  251
# 10       248          248         248  248  248     248  248     248  248
# 11       248          248         248  248  248     248  248     248  248
# 12       249          249         249  249  249     249  249     249  249
# 13       248          248         248  248  248     248  248     248  248
# 14       249          249         249  249  249     249  249     249  249
# 15       254          254         254  254  254     254  254     254  254
# 16       241          241         241  241  241     241  241     241  241
# 17       245          245         245  245  245     245  245     245  245
# 18       241          241         241  241  241     241  241     241  241
# 19       238          238         238  238  238     238  238     238  238
# 20       232          232         232  232  232     232  232     232  232
# 21       223          223         223  223  223     223  223     223  223
# 22       207          207         207  207  207     207  207     207  207
# 23       194          194         194  194  194     194  194     194  194
#
#       BII-6l  ...   C4  B04  C2l  BII-2L  B02  C1b  C2b  B01  C1l  route_v
# hour          ...
# 0        185  ...  185  185  185     185  185  185  185  185  185      185
# 1        153  ...  153  153  153     153  153  153  153  153  153      153
# 2        171  ...  171  171  171     171  171  171  171  171  171      171
# 3        194  ...  194  194  194     194  194  194  194  194  194      194
# 4        211  ...  211  211  211     211  211  211  211  211  211      211
# 5        230  ...  230  230  230     230  230  230  230  230  230      230
# 6        240  ...  240  240  240     240  240  240  240  240  240      240
# 7        242  ...  242  242  242     242  242  242  242  242  242      242
# 8        254  ...  254  254  254     254  254  254  254  254  254      254
# 9        251  ...  251  251  251     251  251  251  251  251  251      251
# 10       248  ...  248  248  248     248  248  248  248  248  248      248
# 11       248  ...  248  248  248     248  248  248  248  248  248      248
# 12       249  ...  249  249  249     249  249  249  249  249  249      249
# 13       248  ...  248  248  248     248  248  248  248  248  248      248
# 14       249  ...  249  249  249     249  249  249  249  249  249      249
# 15       254  ...  254  254  254     254  254  254  254  254  254      254
# 16       241  ...  241  241  241     241  241  241  241  241  241      241
# 17       245  ...  245  245  245     245  245  245  245  245  245      245
# 18       241  ...  241  241  241     241  241  241  241  241  241      241
# 19       238  ...  238  238  238     238  238  238  238  238  238      238
# 20       232  ...  232  232  232     232  232  232  232  232  232      232
# 21       223  ...  223  223  223     223  223  223  223  223  223      223
# 22       207  ...  207  207  207     207  207  207  207  207  207      207
# 23       194  ...  194  194  194     194  194  194  194  194  194      194
#
# [24 rows x 36 columns]

# %%
df_vessels.groupby('route').mean().sort_values('time_in_line', ascending=False)
# Out:
#                             id  generation_hour  time_departed  travel_time  \
# route
# (NLTNZ, NLAMS, 3)  3868.468235        12.178824    3520.720000       1134.0
# (NLTNZ, NLAMS, 0)  4810.250000        12.750000    2923.750000       1038.0
# (NLTNZ, NLMST, 1)  3845.471910        12.831461    3404.134831       1708.0
# (NLSTI, NLTNZ, 1)  3981.539683        12.166667    3212.809524       1646.0
# (NLIJM, NLMST, 1)  3696.439689        13.087549    3924.571984       1377.0
# ...                        ...              ...            ...          ...
# (NLAMS, NLDHR, 0)  4084.527559        12.476378    5570.090551        341.0
# (NLHAR, NLDRA, 0)  4207.063422        13.343658    5721.995575        328.0
# (NLMEP, NLZWS, 0)  4072.170732        11.697561    5859.074797         55.0
# (NLTLB, NLRTM, 0)  3810.000000        12.000000    3454.000000        412.0
# (NLHAR, NLWTE, 0)  4503.612245        12.224490    5891.653061        207.0
#
#                    time_in_line  time_charging  battery_size
# route
# (NLTNZ, NLAMS, 3)   1703.383529    2429.555294  14695.529412
# (NLTNZ, NLAMS, 0)   1646.500000    1731.000000   1750.000000
# (NLTNZ, NLMST, 1)   1634.589888    2708.556180  14097.471910
# (NLSTI, NLTNZ, 1)   1617.753968    2659.277778  13888.492063
# (NLIJM, NLMST, 1)   1613.673152    2157.420233   9222.373541
# ...                         ...            ...           ...
# (NLAMS, NLDHR, 0)      2.767717     210.795276  11088.582677
# (NLHAR, NLDRA, 0)      1.560472      59.615044   4369.911504
# (NLMEP, NLZWS, 0)      1.170732      74.297561  10662.032520
# (NLTLB, NLRTM, 0)      0.000000      41.000000   1750.000000
# (NLHAR, NLWTE, 0)      0.000000      29.938776   3826.530612
#
# [209 rows x 7 columns]

# %%
df_vessels
# Out:
#         id              route                        combi  generation_hour  \
# 0        4  (NLTNZ, NLVLI, 0)                    [8864111]               14
# 1       14  (NLGOR, NLRTM, 0)                    [8863306]               10
# 2       29  (NLDOR, NLRTM, 0)                    [8863306]               20
# 3        7  (NLAMS, NLAER, 0)                    [8864005]               11
# 4       23  (NLRTM, NLGTB, 1)                    [8866893]                3
# ...    ...                ...                          ...              ...
# 1335  7524  (NLRTM, NLAMS, 1)           [8866429, 8862776]               10
# 1336  7946  (NLDST, NLAMS, 0)           [8865412, 8866429]                8
# 1337  7492  (NLVLI, NLAMS, 1)  [8862992, 8866686, 8867392]                9
# 1338  7815  (NLWGW, NLRTM, 0)           [8866686, 8865412]               12
# 1339  7979  (NLAMS, NLAER, 0)                    [8864005]               16
#
#       time_departed  travel_time  time_in_line  time_charging  battery_size
# 0                14          110             0              0         20150
# 1               107          238             0              0          6900
# 2               240          127             0              0          6900
# 3                35          225             0            145          6900
# 4               198          264             0              0          6900
# ...             ...          ...           ...            ...           ...
# 1335           8017          579          2632           2885         14250
# 1336          10921          478             0             84          4350
# 1337           7870         1222          1698           2401         14250
# 1338          10021          506           909            962          3000
# 1339          11197          225             0             92          4350
#
# [136142 rows x 9 columns]

# %%
df_cs = get_cs_data_batch(batch_data)
df_cs
# Out:
#         RunId  iteration   Step    seed  \
# 737         0          0  11520  194081
# 741         0          0  11520  194081
# 750         0          0  11520  194081
# 755         0          0  11520  194081
# 757         0          0  11520  194081
# ...       ...        ...    ...     ...
# 118000     99          0  11520  131322
# 118001     99          0  11520  131322
# 118005     99          0  11520  131322
# 118017     99          0  11520  131322
# 118024     99          0  11520  131322
#
#                                      data_completed_trips   AgentID  \
# 737     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8864153
# 741     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8868208
# 750     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...  30984595
# 755     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8860582
# 757     {'id': [4, 14, 29, 7, 23, 32, 33, 61, 16, 0, 5...   8862419
# ...                                                   ...       ...
# 118000  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8867083
# 118001  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863306
# 118005  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863125
# 118017  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8863518
# 118024  {'id': [6424, 6426, 6427, 6435, 6436, 6461, 64...   8862448
#
#         occupation  max_occupation  avg_line  max_line  charging_stations
# 737       0.239385             1.0  0.015377       1.0                1.0
# 741       0.858631             1.0  1.427480       5.0                1.0
# 750       0.702083             1.0  0.489881       2.0                1.0
# 755       0.026290             1.0  0.000000       0.0                1.0
# 757       0.118452             1.0  0.009325       1.0                1.0
# ...            ...             ...       ...       ...                ...
# 118000    0.162103             1.0  0.014583       1.0                1.0
# 118001    0.885317             1.0  2.335218       7.0                1.0
# 118005    0.267460             1.0  0.075099       1.0                1.0
# 118017    0.022024             1.0  0.000000       0.0                1.0
# 118024    0.335615             1.0  0.034524       1.0                1.0
#
# [4900 rows x 11 columns]

# %%
df_vessels = get_vessel_data_batch(batch_data)
df_vessels.groupby('route').mean().sort_values('time_in_line', ascending=False)
# Out:
#                             id  generation_hour  time_departed  travel_time  \
# route
# (NLTNZ, NLAMS, 3)  3868.468235        12.178824    3520.720000       1134.0
# (NLTNZ, NLAMS, 0)  4810.250000        12.750000    2923.750000       1038.0
# (NLTNZ, NLMST, 1)  3845.471910        12.831461    3404.134831       1708.0
# (NLSTI, NLTNZ, 1)  3981.539683        12.166667    3212.809524       1646.0
# (NLIJM, NLMST, 1)  3696.439689        13.087549    3924.571984       1377.0
# ...                        ...              ...            ...          ...
# (NLAMS, NLDHR, 0)  4084.527559        12.476378    5570.090551        341.0
# (NLHAR, NLDRA, 0)  4207.063422        13.343658    5721.995575        328.0
# (NLMEP, NLZWS, 0)  4072.170732        11.697561    5859.074797         55.0
# (NLTLB, NLRTM, 0)  3810.000000        12.000000    3454.000000        412.0
# (NLHAR, NLWTE, 0)  4503.612245        12.224490    5891.653061        207.0
#
#                    time_in_line  time_charging  battery_size
# route
# (NLTNZ, NLAMS, 3)   1703.383529    2429.555294  14695.529412
# (NLTNZ, NLAMS, 0)   1646.500000    1731.000000   1750.000000
# (NLTNZ, NLMST, 1)   1634.589888    2708.556180  14097.471910
# (NLSTI, NLTNZ, 1)   1617.753968    2659.277778  13888.492063
# (NLIJM, NLMST, 1)   1613.673152    2157.420233   9222.373541
# ...                         ...            ...           ...
# (NLAMS, NLDHR, 0)      2.767717     210.795276  11088.582677
# (NLHAR, NLDRA, 0)      1.560472      59.615044   4369.911504
# (NLMEP, NLZWS, 0)      1.170732      74.297561  10662.032520
# (NLTLB, NLRTM, 0)      0.000000      41.000000   1750.000000
# (NLHAR, NLWTE, 0)      0.000000      29.938776   3826.530612
#
# [209 rows x 7 columns]

# %% [markdown]
# # Process results ABM runs

# %%
import pickle
import numpy as np
from os import walk
f = []
for (dirpath, dirnames, filenames) in walk('ABM/own_work/results/'):
    f.extend(filenames)
    break

# %%
all_cs_data = {'r':[], 'c':[], 'm':[], 'stations_per_loc':[], 'avg_occ':[], 'avg_line':[], 'avg_max_line':[]}
all_cs_data_full = {'r':[], 'c':[], 'm':[], 'stations_per_loc':[], 'avg_occ':[], 'avg_line':[], 'avg_max_line':[]}
all_vessel_data = {'r':[], 'c':[], 'm':[], 'supported_routes':[], 'avg_travel':[], 'avg_inline':[], 'avg_charging':[],
                   'frac_charging':[], 'frac_inline':[], 'frac_driving':[], 'battery_size':[], 'total_charged':[]}

# %%
df_cs_all = pd.DataFrame()

# %%
for filename in f:
    r = int(filename[16:19].replace('.',''))
    m = int(filename.split('.')[1][-1])
    c = int(10000/m)

    df = pickle.load(open('ABM/own_work/results/'+str(filename), 'rb'))
    df = pd.DataFrame(df)
    df_cs = get_cs_data_batch(df)
    df_vessels = get_vessel_data_batch(df)

    df_cs['c'] = c
    df_cs['r'] = r
    df_cs['m'] = m

    df_cs_all =  pd.concat([df_cs_all, df_cs])

    all_cs_data['avg_occ'].append(df_cs.occupation.mean())
    all_cs_data['avg_max_line'].append(df_cs.max_line.mean())
    all_cs_data['avg_line'].append(df_cs.avg_line.mean())
    all_cs_data['stations_per_loc'].append(df_cs.charging_stations.mean())

    df_vessels['frac_inline'] = df_vessels.apply(lambda x: x.time_in_line / (x.travel_time + x.time_in_line + x.time_charging), axis=1)
    df_vessels['frac_charging'] = df_vessels.apply(lambda x: x.time_charging / (x.travel_time + x.time_in_line + x.time_charging), axis=1)
    df_vessels['frac_not_driving'] = df_vessels['frac_charging'] + df_vessels['frac_inline']
    df_vessels['frac_driving'] = 1 - df_vessels['frac_not_driving']

    df_vessels_mean = df_vessels.groupby('route').mean()

    all_vessel_data['supported_routes'].append(len(df_vessels_mean))
    all_vessel_data['avg_travel'].append(df_vessels_mean.travel_time.mean())
    all_vessel_data['avg_charging'].append(df_vessels_mean.time_charging.mean())
    all_vessel_data['avg_inline'].append(df_vessels_mean.time_in_line.mean())
    all_vessel_data['frac_charging'].append(df_vessels_mean.frac_charging.mean())
    all_vessel_data['frac_inline'].append(df_vessels_mean.frac_inline.mean())
    all_vessel_data['frac_driving'].append(df_vessels_mean.frac_driving.mean())
    all_vessel_data['battery_size'].append(df_vessels_mean.battery_size.mean())
    all_vessel_data['total_charged'].append(df_vessels.total_charged)


    all_vessel_data['r'].append(r)
    all_vessel_data['c'].append(c)
    all_vessel_data['m'].append(m)
    all_cs_data['r'].append(r)
    all_cs_data['c'].append(c)
    all_cs_data['m'].append(m)

# %%
cs_df = pd.DataFrame(all_cs_data)
vessel_df = pd.DataFrame(all_vessel_data)

# %%
cs_df.to_excel('final_results/cs_data_abm.xlsx')
vessel_df.to_excel('final_results/vessel_data_abm.xlsx')

# %%
vessel_df.sort_values('r', inplace=True)

# %%
vessel_df
# Out:
#      r      c  m  supported_routes  avg_travel  avg_inline  avg_charging  \
# 6   70  10000  1               188  511.036252  296.633317     56.978037
# 7   70   2000  5               188  510.417633  831.406876    280.288054
# 8   70   3333  3               188  511.381933  693.812764    170.516074
# 0  110  10000  1               187  508.888553  206.429402     62.666304
# 1  110   2000  5               188  509.762010  437.710747    296.944378
# 2  110   3333  3               187  509.645952  392.700708    181.433978
# 3  150  10000  1               187  509.300902  153.131639     68.120325
# 4  150   2000  5               187  510.007520  528.661197    323.582876
# 5  150   3333  3               186  507.529872  453.972538    194.541902
#
#    frac_charging  frac_inline  frac_driving  battery_size  \
# 6       0.081754     0.159149      0.759097   5352.097874
# 7       0.207713     0.343940      0.448346   5347.592470
# 8       0.152901     0.334970      0.512130   5358.945396
# 0       0.088993     0.179638      0.731369   8372.268247
# 1       0.247040     0.213446      0.539514   8383.164324
# 2       0.180924     0.215965      0.603111   8448.797492
# 3       0.101577     0.130134      0.768288  11432.791141
# 4       0.248862     0.234583      0.516554  11509.458632
# 5       0.191907     0.233997      0.574096  11459.434656
#
#                                        total_charged
# 6  0        89
# 1        48
# 2        25
# 3        7...
# 7  0       160
# 1         0
# 2       418
# 3       10...
# 8  0         0
# 1       312
# 2       325
# 3        6...
# 0  0        21
# 1        11
# 2         0
# 3        4...
# 1  0       429
# 1       123
# 2       443
# 3       10...
# 2  0       182
# 1       177
# 2        30
# 3       12...
# 3  0        45
# 1       104
# 2        32
# 3         ...
# 4  0         0
# 1       126
# 2       469
# 3       21...
# 5  0       238
# 1       339
# 2       113
# 3       22...

# %%
# labels1 = vessel_df.apply(lambda x: x.r.astype(str)[:3]+'km_'+x.m.astype(str)[:1]+'x'+x.c.astype(str)[:4], axis=1).to_list()
labels1 =['70km_1x10MW',
 '70km_5x2MW',
 '70km_3x3.3MW',
 '110km_1x10MW',
 '110km_5x2MW',
 '110km_3x3.3MW',
 '150km_1x10MW',
 '150km_5x2MW',
 '150km_3x3.3MW']

# %%
vessel_df_fractions =vessel_df.drop(columns=['supported_routes', 'avg_inline', 'avg_charging', 'avg_travel', 'total_charged', 'battery_size'])
vessel_df_fractions = vessel_df_fractions.iloc[:,3:]

# %%
vessel_df_fractions
# Out:
#    frac_charging  frac_inline  frac_driving
# 6       0.081754     0.159149      0.759097
# 7       0.207713     0.343940      0.448346
# 8       0.152901     0.334970      0.512130
# 0       0.088993     0.179638      0.731369
# 1       0.247040     0.213446      0.539514
# 2       0.180924     0.215965      0.603111
# 3       0.101577     0.130134      0.768288
# 4       0.248862     0.234583      0.516554
# 5       0.191907     0.233997      0.574096

# %% [markdown]
# Looks okay, now lets make some plots

# %%
vessel_df
# Out:
#      r      c  m  supported_routes  avg_travel  avg_inline  avg_charging  \
# 6   70  10000  1               188  511.036252  296.633317     56.978037
# 7   70   2000  5               188  510.417633  831.406876    280.288054
# 8   70   3333  3               188  511.381933  693.812764    170.516074
# 0  110  10000  1               187  508.888553  206.429402     62.666304
# 1  110   2000  5               188  509.762010  437.710747    296.944378
# 2  110   3333  3               187  509.645952  392.700708    181.433978
# 3  150  10000  1               187  509.300902  153.131639     68.120325
# 4  150   2000  5               187  510.007520  528.661197    323.582876
# 5  150   3333  3               186  507.529872  453.972538    194.541902
#
#    frac_charging  frac_inline  frac_driving  battery_size  \
# 6       0.081754     0.159149      0.759097   5352.097874
# 7       0.207713     0.343940      0.448346   5347.592470
# 8       0.152901     0.334970      0.512130   5358.945396
# 0       0.088993     0.179638      0.731369   8372.268247
# 1       0.247040     0.213446      0.539514   8383.164324
# 2       0.180924     0.215965      0.603111   8448.797492
# 3       0.101577     0.130134      0.768288  11432.791141
# 4       0.248862     0.234583      0.516554  11509.458632
# 5       0.191907     0.233997      0.574096  11459.434656
#
#                                        total_charged
# 6  0        89
# 1        48
# 2        25
# 3        7...
# 7  0       160
# 1         0
# 2       418
# 3       10...
# 8  0         0
# 1       312
# 2       325
# 3        6...
# 0  0        21
# 1        11
# 2         0
# 3        4...
# 1  0       429
# 1       123
# 2       443
# 3       10...
# 2  0       182
# 1       177
# 2        30
# 3       12...
# 3  0        45
# 1       104
# 2        32
# 3         ...
# 4  0         0
# 1       126
# 2       469
# 3       21...
# 5  0       238
# 1       339
# 2       113
# 3       22...

# %%
## Charging stations
vessel_df_copy = vessel_df.copy()
vessel_df_copy.c = vessel_df_copy.c.apply(lambda x: "5x2MW" if x == 2000 else x)
vessel_df_copy.c = vessel_df_copy.c.apply(lambda x: "3x3.3MW" if x == 3333 else x)
vessel_df_copy.c = vessel_df_copy.c.apply(lambda x: "1x10MW" if x == 10000 else x)
fig, ax = plt.subplots(dpi=200)
sns.barplot(x='r', y='avg_inline', data=vessel_df_copy, hue='c')
plt.xlabel('Range [km] of a ship ')
plt.ylabel('Average time [min] in line')
ax.legend(title="Max per loc", loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig, ax = plt.subplots(dpi=200)
sns.barplot(x='r', y='avg_charging', data=vessel_df_copy, hue='c')
plt.xlabel('Range [km] of a ship ')
plt.ylabel('Average time [min] charging')
ax.legend(title="Max per loc", loc='center left', bbox_to_anchor=(1, 0.5))

# %%
vessel_df_fractions
# Out:
#    frac_charging  frac_inline  frac_driving
# 6       0.081754     0.159149      0.759097
# 7       0.207713     0.343940      0.448346
# 8       0.152901     0.334970      0.512130
# 0       0.088993     0.179638      0.731369
# 1       0.247040     0.213446      0.539514
# 2       0.180924     0.215965      0.603111
# 3       0.101577     0.130134      0.768288
# 4       0.248862     0.234583      0.516554
# 5       0.191907     0.233997      0.574096

# %%
fig, ax = plt.subplots(dpi=200)
vessel_df_fractions.index=labels1
vessel_df_fractions.plot(kind='bar', stacked=True, color=['red', 'skyblue', 'green'], ax=ax)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),labels=["Charging", "In line", "Driving"])
plt.xlabel('Scenario')
plt.ylabel('Average fraction [-] total trip duration')
plt.show()

# %% [markdown]
# ## Charging station data

# %%
cs_df
# Out:
#      r      c  m  stations_per_loc   avg_occ  avg_line  avg_max_line
# 0  110  10000  1          1.000000  0.153127  0.534119      2.073148
# 1  110   2000  5          1.310345  0.642572  1.147206      3.752241
# 2  110   3333  3          1.122807  0.405734  1.123445      3.481930
# 3  150  10000  1          1.000000  0.200568  0.653101      2.411333
# 4  150   2000  5          1.388889  0.721435  1.679038      4.601296
# 5  150   3333  3          1.122449  0.489117  1.300360      3.898980
# 6   70  10000  1          1.000000  0.115517  0.716816      2.202381
# 7   70   2000  5          1.187500  0.510441  1.902393      5.139531
# 8   70   3333  3          1.063492  0.326237  1.726776      4.581905

# %%
cs_df['utilisation'] = cs_df['avg_occ']/cs_df['stations_per_loc']

# %%
cs_df_copy = cs_df.copy()
cs_df_copy.c = cs_df_copy.c.apply(lambda x: "5x2MW" if x == 2000 else x)
cs_df_copy.c = cs_df_copy.c.apply(lambda x: "3x3.3MW" if x == 3333 else x)
cs_df_copy.c = cs_df_copy.c.apply(lambda x: "1x10MW" if x == 10000 else x)

# %%
cs_df
# Out:
#      r      c  m  stations_per_loc   avg_occ  avg_line  avg_max_line  \
# 0  110  10000  1          1.000000  0.153127  0.534119      2.073148
# 1  110   2000  5          1.310345  0.642572  1.147206      3.752241
# 2  110   3333  3          1.122807  0.405734  1.123445      3.481930
# 3  150  10000  1          1.000000  0.200568  0.653101      2.411333
# 4  150   2000  5          1.388889  0.721435  1.679038      4.601296
# 5  150   3333  3          1.122449  0.489117  1.300360      3.898980
# 6   70  10000  1          1.000000  0.115517  0.716816      2.202381
# 7   70   2000  5          1.187500  0.510441  1.902393      5.139531
# 8   70   3333  3          1.063492  0.326237  1.726776      4.581905
#
#    utilisation
# 0     0.153127
# 1     0.490384
# 2     0.361357
# 3     0.200568
# 4     0.519433
# 5     0.435759
# 6     0.115517
# 7     0.429845
# 8     0.306760

# %%
cs_df['utilisation'] = cs_df['avg_occ']/cs_df['stations_per_loc']

# %%
fig, ax = plt.subplots(dpi=200)
sns.barplot(x='r', y='utilisation', data=cs_df_copy, hue='c')
plt.xlabel('Range [km] of a ship')
plt.ylabel('Average utilisation [-] charging stations')
ax.legend(title="Max per loc", loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
cs_df
# Out:
#      r      c  m  stations_per_loc   avg_occ  avg_line  avg_max_line  \
# 0  110  10000  1          1.000000  0.153127  0.534119      2.073148
# 1  110   2000  5          1.310345  0.642572  1.147206      3.752241
# 2  110   3333  3          1.122807  0.405734  1.123445      3.481930
# 3  150  10000  1          1.000000  0.200568  0.653101      2.411333
# 4  150   2000  5          1.388889  0.721435  1.679038      4.601296
# 5  150   3333  3          1.122449  0.489117  1.300360      3.898980
# 6   70  10000  1          1.000000  0.115517  0.716816      2.202381
# 7   70   2000  5          1.187500  0.510441  1.902393      5.139531
# 8   70   3333  3          1.063492  0.326237  1.726776      4.581905
#
#    utilisation
# 0     0.153127
# 1     0.490384
# 2     0.361357
# 3     0.200568
# 4     0.519433
# 5     0.435759
# 6     0.115517
# 7     0.429845
# 8     0.306760

# %%
occupation = cs_df.loc[:,['avg_occ']]/cs_df.loc[:,[ 'stations_per_loc']]

# %%
plt.subplots(dpi=200)
import numpy as np
X = labels1

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, cs_df.stations_per_loc, 0.4, label = 'Average stations per location')
plt.bar(X_axis + 0.2, cs_df.avg_occ, 0.4, label = 'Average occupation')

plt.xticks(X_axis, X, rotation=90)
plt.xlabel("Scenario")
# plt.ylabel("")
# plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %%
cs_df
# Out:
#      r      c  m  stations_per_loc   avg_occ  avg_line  avg_max_line  \
# 0  110  10000  1          1.000000  0.153127  0.534119      2.073148
# 1  110   2000  5          1.310345  0.642572  1.147206      3.752241
# 2  110   3333  3          1.122807  0.405734  1.123445      3.481930
# 3  150  10000  1          1.000000  0.200568  0.653101      2.411333
# 4  150   2000  5          1.388889  0.721435  1.679038      4.601296
# 5  150   3333  3          1.122449  0.489117  1.300360      3.898980
# 6   70  10000  1          1.000000  0.115517  0.716816      2.202381
# 7   70   2000  5          1.187500  0.510441  1.902393      5.139531
# 8   70   3333  3          1.063492  0.326237  1.726776      4.581905
#
#    utilisation
# 0     0.153127
# 1     0.490384
# 2     0.361357
# 3     0.200568
# 4     0.519433
# 5     0.435759
# 6     0.115517
# 7     0.429845
# 8     0.306760

# %%
plt.subplots(dpi=200)
import numpy as np
X = labels1

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, cs_df.avg_line, 0.4, label = 'Average line length')
plt.bar(X_axis + 0.2, cs_df.avg_max_line, 0.4, label = 'Average max line length')

plt.xticks(X_axis, X, rotation=90)
plt.xlabel("Scenario")
# plt.ylabel("")
# plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %% [markdown]
# ## Explore variables

# %%
df = pickle.load(open('ABM/own_work/results/batch_9scenarios70.0100001.p', 'rb'))
df = pd.DataFrame(df)
df_cs = get_cs_data_batch(df)
df_vessels = get_vessel_data_batch(df)

# %%
df_vessels
# Out:
#         id              route                        combi  generation_hour  \
# 0       97  (NLRTM, NLAMS, 1)  [8863272, 8867392, 8862776]               15
# 1      147  (NLMOE, NLAPN, 1)           [8863360, 8867130]               16
# 2      120  (NLDST, NLAMS, 0)           [8860631, 8865887]               21
# 3       94  (NLHAS, NLAMS, 0)      [117, 8861499, 8863272]               12
# 4      177  (NLRTM, NLZWI, 0)                    [8863306]               23
# ...    ...                ...                          ...              ...
# 1274  1365  (NLRTM, NLAMS, 2)      [8863306, 8865887, 122]                2
# 1275  1421  (NLRTM, NLOOS, 1)           [8866686, 8863818]               13
# 1276  1387  (NLRTM, NLLAV, 0)  [8863306, 8865887, 8863360]               13
# 1277  1399  (NLLEY, NLAMS, 0)           [8863272, 8861499]                5
# 1278  1380  (NLVEG, NLRTM, 0)  [8864151, 8866775, 8863306]               20
#
#       time_departed  travel_time  time_in_line  time_charging  battery_size  \
# 0               723          642             0             89          6980
# 1              1066          351             0             39          6980
# 2               875          512            60             25          2160
# 3               695          682             0            112          6980
# 4              1366          140             0              0          6980
# ...             ...          ...           ...            ...           ...
# 1274          10670          603           115             95          9759
# 1275          11145          318             0             34          6980
# 1276          10877          513             0            113          8949
# 1277          10991          464            50             13          1447
# 1278          10835          665             0             23          1447
#
#       total_charged
# 0           226.662
# 1           226.662
# 2           234.960
# 3           226.662
# 4           226.662
# ...             ...
# 1274        241.620
# 1275        226.662
# 1276        214.980
# 1277        201.660
# 1278        201.660
#
# [1279 rows x 10 columns]

# %%
df_cs.occupation.mean()
# Out:
# 0.11422466422466425

# %%
df_cs.max_line.mean()
# Out:
# 1.2461538461538462

# %%
df_cs.avg_line.mean()
# Out:
# 0.06779151404151404

# %%
df_cs.charging_stations.mean()
# Out:
# 1.0

# %%
df_vessels
# Out:
#         id              route                             combi  \
# 0      151  (NLRTM, NLOOS, 1)                [8866686, 8863818]
# 1       70  (NLRTM, NLVLI, 0)      [8864258, 105, 120, 8867130]
# 2      162  (NLGOR, NLRTM, 0)                [8863306, 8864151]
# 3      117  (NLKAM, NLAMS, 0)       [8863272, 8861499, 8868191]
# 4       56  (NLAMS, NLEUR, 1)           [8863206, 8865887, 122]
# ...    ...                ...                               ...
# 1357  1525  (NLRTM, NLMOE, 0)               [30984595, 8863306]
# 1358  1464  (NLZWO, NLAMS, 0)       [8863272, 8861499, 8868191]
# 1359  1508  (NLRTM, NLOOS, 1)                [8866686, 8863818]
# 1360  1446  (NLAMS, NLDEV, 0)  [8863272, 8861499, 8868191, 109]
# 1361  1453  (NLPER, NLAMS, 3)  [8863206, 8863272, 8867392, 122]
#
#       generation_hour  time_departed  travel_time  time_in_line  \
# 0                  10           1035          318            25
# 1                  11            499          838             0
# 2                  11           1158          255            15
# 3                  10            840          561            40
# 4                   0            390          838            54
# ...               ...            ...          ...           ...
# 1357                1          11231          208             0
# 1358               12          10729          680            23
# 1359               18          11126          318             0
# 1360               20          10591          861             0
# 1361                6          10650          711            41
#
#       time_charging  battery_size    speed
# 0                65          6980  226.662
# 1               117          6980  226.662
# 2                28          3427  234.960
# 3                24          2160  234.960
# 4               192         11168  233.280
# ...             ...           ...      ...
# 1357             29          6980  226.662
# 1358             50          3427  234.960
# 1359             34          6980  226.662
# 1360             64          3427  234.960
# 1361            119          6980  226.662
#
# [1362 rows x 10 columns]

# %%
df_vessels['frac_inline'] = df_vessels.apply(lambda x: x.time_in_line/(x.travel_time+x.time_in_line+x.time_charging), axis=1)
df_vessels['frac_charging'] = df_vessels.apply(lambda x: x.time_charging/(x.travel_time+x.time_in_line+x.time_charging), axis=1)
df_vessels['frac_not_driving'] = df_vessels['frac_charging'] + df_vessels['frac_charging']
df_vessels['frac_driving'] = 1-df_vessels['frac_not_driving']

# %%
df_vessels.speed
# Out:
# 0       226.662
# 1       226.662
# 2       234.960
# 3       234.960
# 4       233.280
#          ...
# 1357    226.662
# 1358    234.960
# 1359    226.662
# 1360    234.960
# 1361    226.662
# Name: speed, Length: 1362, dtype: float64

# %%
df_vessels_mean = df_vessels.groupby('route').mean()

# %%
df_vessels_mean
# Out:
#                             id  generation_hour  time_departed  travel_time  \
# route
# (NLABL, NLRTM, 0)  3894.200000        11.170874    5607.155340    77.782524
# (NLAER, NLLEY, 0)  3785.312232        10.958155    5221.742489   169.119099
# (NLAER, NLSWI, 0)  3934.321168        11.629197    5581.864234   251.233577
# (NLALK, NLIJM, 0)  2919.943396        12.452830     289.566038   279.962264
# (NLALM, NLHGL, 0)  3747.420582        12.814318    5886.154362   137.718121
# ...                        ...              ...            ...          ...
# (NLWSP, NLAER, 0)  3710.240061        11.558869    5234.017584   198.899847
# (NLWSP, NLLEY, 0)  3454.350993        11.178808    2138.887417   356.430464
# (NLZAA, NLRTM, 0)  3592.333333        11.666667     125.333333   467.000000
# (NLZWO, NLAMS, 0)  3207.310056        12.231844    1221.472067   715.863128
# (NLZWS, NLAMS, 0)  3519.276730        12.402516    2213.679245   692.144654
#
#                    time_in_line  time_charging   battery_size  frac_inline  \
# route
# (NLABL, NLRTM, 0)    404.930097     668.833010  783113.122330     0.033407
# (NLAER, NLLEY, 0)    748.465665    1060.335837  235458.931330     0.137674
# (NLAER, NLSWI, 0)    888.681752     900.078832  210015.500730     0.220003
# (NLALK, NLIJM, 0)   5246.849057    5886.000000  210745.188679     0.443881
# (NLALM, NLHGL, 0)    241.760626     870.586130  456856.767338     0.054634
# ...                         ...            ...            ...          ...
# (NLWSP, NLAER, 0)    644.366208    1097.950306  374956.678899     0.110778
# (NLWSP, NLLEY, 0)   2733.006623    3818.238411  357001.013245     0.339299
# (NLZAA, NLRTM, 0)   6405.333333    6420.666667  157914.666667     0.477374
# (NLZWO, NLAMS, 0)   4544.740223    5004.310056  370180.192737     0.421901
# (NLZWS, NLAMS, 0)   3398.427673    3455.515723  401382.295597     0.421127
#
#                    frac_charging  frac_not_driving  frac_driving
# route
# (NLABL, NLRTM, 0)       0.079670          0.113077      0.886923
# (NLAER, NLLEY, 0)       0.267137          0.404811      0.595189
# (NLAER, NLSWI, 0)       0.244483          0.464486      0.535514
# (NLALK, NLIJM, 0)       0.521631          0.965512      0.034488
# (NLALM, NLHGL, 0)       0.366056          0.420690      0.579310
# ...                          ...               ...           ...
# (NLWSP, NLAER, 0)       0.269949          0.380727      0.619273
# (NLWSP, NLLEY, 0)       0.579284          0.918584      0.081416
# (NLZAA, NLRTM, 0)       0.478551          0.955926      0.044074
# (NLZWO, NLAMS, 0)       0.476628          0.898529      0.101471
# (NLZWS, NLAMS, 0)       0.433523          0.854650      0.145350
#
# [149 rows x 11 columns]

# %%
len(df_vessels_mean)
# Out:
# 209

# %%
df_vessels_mean.travel_time.mean()
# Out:
# 551.061862942879

# %%
df_vessels_mean.time_charging.mean()
# Out:
# 796.2090248437966

# %%
df_vessels_mean.time_in_line.mean()
# Out:
# 543.0992398999723

# %%
df_vessels_mean.frac_charging.mean()
# Out:
# 0.3396765740319129

# %%
df_vessels_mean.frac_inline.mean()
# Out:
# 0.17521269085821115

# %%
df_vessels_mean.frac_driving.mean()
# Out:
# 0.320646851936174

# %% [markdown]
# ## plots routes

# %%
df_cs_all
# Out:
#         RunId  iteration   Step      c    r  run    seed  \
# 818         0          0  11520  10000  110    3   23939
# 825         0          0  11520  10000  110    3   23939
# 826         0          0  11520  10000  110    3   23939
# 828         0          0  11520  10000  110    3   23939
# 832         0          0  11520  10000  110    3   23939
# ...       ...        ...    ...    ...  ...  ...     ...
# 120404     99          0  11520   3333   70    1  295376
# 120406     99          0  11520   3333   70    1  295376
# 120407     99          0  11520   3333   70    1  295376
# 120408     99          0  11520   3333   70    1  295376
# 120409     99          0  11520   3333   70    1  295376
#
#                                      data_completed_trips  AgentID  \
# 818     {'id': [140, 83, 53, 102, 61, 110, 108, 125, 1...  8863272
# 825     {'id': [140, 83, 53, 102, 61, 110, 108, 125, 1...  8863206
# 826     {'id': [140, 83, 53, 102, 61, 110, 108, 125, 1...  8861546
# 828     {'id': [140, 83, 53, 102, 61, 110, 108, 125, 1...  8864258
# 832     {'id': [140, 83, 53, 102, 61, 110, 108, 125, 1...  8863306
# ...                                                   ...      ...
# 120404  {'id': [6259, 6256, 6254, 6132, 6125, 6243, 61...      120
# 120406  {'id': [6259, 6256, 6254, 6132, 6125, 6243, 61...      122
# 120407  {'id': [6259, 6256, 6254, 6132, 6125, 6243, 61...      123
# 120408  {'id': [6259, 6256, 6254, 6132, 6125, 6243, 61...      124
# 120409  {'id': [6259, 6256, 6254, 6132, 6125, 6243, 61...      125
#
#         occupation  max_occupation  avg_line  max_line  charging_stations  m
# 818       0.760615             1.0  0.905853       6.0                1.0  1
# 825       0.031151             1.0  0.000000       0.0                1.0  1
# 826       0.023710             1.0  0.000000       0.0                1.0  1
# 828       0.432044             1.0  0.154563       4.0                1.0  1
# 832       0.569742             1.0  0.680655       5.0                1.0  1
# ...            ...             ...       ...       ...                ... ..
# 120404    0.648512             1.0  0.510516       3.0                1.0  3
# 120406    2.648710             3.0  3.012004      13.0                3.0  3
# 120407    0.017262             1.0  0.000000       0.0                1.0  3
# 120408    0.039980             1.0  0.000000       0.0                1.0  3
# 120409    0.000000             0.0  0.000000       0.0                1.0  3
#
# [53000 rows x 15 columns]

# %%
len(df_cs_all.loc[df_cs_all.c==2000].AgentID.unique())
# Out:
# 93

# %%
import numpy as np
for i in [2000, 3333, 10000]:
    fig, ax = plt.subplots(dpi=200, figsize = (12,6))
    plot_df = df_cs_all.loc[df_cs_all.c==i]
    sns.boxplot(x=plot_df.AgentID, y=plot_df.occupation/plot_df.charging_stations, ax=ax)
    ax.set_xlabel('Charging station ID')
    ax.set_ylabel('Utilisation [-]')
    ax.set_xticks([])
    # plt.title('Average occupation charging stations')

# %%
for i in [2000, 3333, 10000]:
    fig, ax = plt.subplots(dpi=200, figsize = (12,6))
    plot_df = df_cs_all.loc[df_cs_all.c==i]
    sns.boxplot(x='AgentID', y='avg_line', data=plot_df)
    plt.title('Average line length')
    ax.set_xlabel('Charging station ID')
    ax.set_ylabel('Average waiting line [# ships]')
    ax.set_xticks([])
