# %%
from fullfrlm import flow_refueling_location_model
from first_stage_frlm import first_stage_frlm

# %%
total_flow, supported_flow, fraction_captured_total, serviceable_fraction, served_fraction, optimal_facilities, \
        non_zero_flows, routes_supported, paths, G, df_abm, df_random = flow_refueling_location_model(1, 0, 70000, 15000, 175, 40, 600, 2, o=24, random_data=False, additional_nodes=True, include_intersections=True, vis=True)
# Out:
# There were 25 nodes added, the longest remaining link is now: 34588.667517419424
# C:\Users\Fabia\Documents\GitHub\Thesis\determine_additional_nodes.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intersections.n = df_intersections.index
# C:\Users\Fabia\Documents\GitHub\Thesis\determine_additional_nodes.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intersections['sum_adjacent'] = df_intersections.apply(lambda x: calc_max_l_adjacent(x.n, G), axis=1)
# ...

# %%
supported_flow
# Out:
# 330.05583719665964

# %%
serviceable_fraction
# Out:
# 0.7216063487643232

# %%
total_flow, fraction_captured_total, serviceable_fraction, served_fraction, optimal_facilities, \
        non_zero_flows, routes_supported, paths, G, df_abm, df_random, max_supported = flow_refueling_location_model(1, 0, 80000, 15000, 175, 40, 600, 2, o=24, random_data=False, additional_nodes=True, include_intersections=True, vis=True)
# Out:
# There were 15 nodes added, the longest remaining link is now: 39728.317897159286
# C:\Users\Fabia\Documents\GitHub\Thesis\determine_additional_nodes.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intersections.n = df_intersections.index
# C:\Users\Fabia\Documents\GitHub\Thesis\determine_additional_nodes.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intersections['sum_adjacent'] = df_intersections.apply(lambda x: calc_max_l_adjacent(x.n, G), axis=1)
# ...

# %%
supported_flow
# Out:
# 331.4829160081055

# %%
serviceable_fraction
# Out:
# 0.6678847729360735
